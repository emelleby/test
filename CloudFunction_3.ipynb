# %% [markdown]
# <a href="https://colab.research.google.com/github/emelleby/test/blob/master/CloudFunction_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install dependencies

# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (0.12.0)

# %% [markdown]
# #Header

# %%
import json
import copy
import os
import xmltodict
from google.cloud import storage
from pymongo import MongoClient


def replace(some_dict):
    return { k: ('' if v is None else v) for k, v in some_dict.items() }

def env_vars():
    return "mongodb+srv://eivind:p7pTfAdW11IwWVBg@cluster0.kbnb5.mongodb.net/example?retryWrites=true&w=majority"
    #return os.environ.get('MONGO', 'Specified environment variable is not set.')

class Connect(object):
    @staticmethod
    def get_connection():
        return MongoClient(env_vars())

# %%
# Transaction function to get the journals
def transactions(journals):
    print("Journals:", journals)

    print(type(journals))

    if (type(journals)) == dict:
        print("Dict")
        journal = journals
        print(journal["Type"])

    else:

        for journal in journals:

            if journal["Type"] == "AP":
                apDict = journal["Transaction"]
                return apDict # print("apDict->", apDict)

            elif journal["Type"] == "A":
                aDict = journal
                return aDict # print("A")

            elif journal["Type"] == "GL":
                glDict = journal
                return glDict # print("GL")

            else:
                print("Ledger not found")

# %% [markdown]
# #Class Company

# %%
class Company:
    def __init__(self, header, suppliers, journal, kontoplan):
        self.RegistrationNumber = header["Company"]["RegistrationNumber"]
        self.Name = header["Company"]["Name"]
        self.ContactPerson = header["Company"]["Contact"]["ContactPerson"]
        self.DefaultCurrencyCode = header["DefaultCurrencyCode"]
        self.Address = []
        self.Accounts = {}
        self.Suppliers = []
        self.Transactions = []        

        self.setAddress(header)

        self.setTransactions(journal)
        self.setSuppliers(suppliers)
        self.setKontoplan(kontoplan)

    def __str__(self):
        return f'''
Org.nr.: {self.RegistrationNumber}
Navn: {self.Name}
Adresse: {self.Address}
Kontakt: {self.ContactPerson}\n
Kontoplan: {len(self.Accounts)}
Leverandør 1: {len(self.Suppliers)}
Transaksjoner: {len(self.Transactions)}
'''

    # Set suppliers
    def setSuppliers(self, suppliers):
        for supplier in suppliers:
            # print(supplier)
            supplier = Supplier(supplier)
            self.Suppliers.append(supplier)

    def getSuppliers(self):
        sups = {
            "RegistrationNumber": self.RegistrationNumber,
            "Name": self.Name,
            "Suppliers": []
            }

        for supplier in self.Suppliers:
            sups["Suppliers"].append(supplier.getSupplier())

        return sups

    # Set Transactions
    def setTransactions(self, journal):
        for trans in journal:
            trans = Transaction(trans)
            self.Transactions.append(trans)

    def getTransactions(self):
        trans = {
            "RegistrationNumber": self.RegistrationNumber,
            "Name": self.Name,
            "Transactions": []
            }

        for transaction in self.Transactions:
            trans["Transactions"].append(transaction.getTransaction())

        return trans

    # Set Kontoplan
    def setKontoplan(self, kontoPlan):
        self.Accounts = kontoPlan

    def getAccounts(self):
        accounts = {
            "RegistrationNumber": self.RegistrationNumber,
            "Name": self.Name,
            "Accounts": self.Accounts
            }

        return accounts

       # Set Address
    def setAddress(self, header):
        if isinstance(header["Company"]['Address'], dict):
            self.Address.append(header["Company"]['Address'])
        else:
            self.Address = header["Company"]['Address']

    # A try to directly return the instance not working as wanted
    def getCompanyDict(self):
        return copy.deepcopy(self.__dict__)

    


    # get Company
    # Need to build the object because otherwise I will return the object reference and not the object info
    def getCompany(self):
        selskap = {
            "RegistrationNumber": self.RegistrationNumber,
            "Name": self.Name,
            "ContactPerson": self.ContactPerson,
            "DefaultCurrencyCode": self.DefaultCurrencyCode,
            "Address": self.Address,
            "Accounts": self.Accounts,
            "Suppliers": [],
            "Transactions": []
            }

        for supplier in self.Suppliers:
            selskap["Suppliers"].append(supplier.getSupplier())

        for trans in self.Transactions:
            selskap["Transactions"].append(trans.getTransaction())

        return selskap

# %%
# companyJson = json.dumps(Company.getCompany(test))
with open("/content/suppliers.json", "w") as sups:
    sups.write(json.dumps(Company.getSuppliers(test)))
print(Company.getSuppliers(test))
# Out:
# {'RegistrationNumber': '918874224', 'Name': 'Accountflow AS', 'Suppliers': [{'RegistrationNumber': '971228865', 'Name': 'Stiftelsen Handelshøyskolen Bi', 'SupplierID': 'PKEY6377196', 'ClosingCreditBalance': '', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'StreetName': 'Nydalsveien 37', 'City': 'Oslo', 'PostalCode': '0484', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'City': 'Oslo', 'PostalCode': '0442', 'Country': 'NO', 'AddressType': 'BillingAddress'}]}, {'RegistrationNumber': '', 'Name': 'Diverse leverandør', 'SupplierID': 'PKEY8182428', 'ClosingCreditBalance': '', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'City': 'Ukjent', 'PostalCode': 'Ukjent', 'AddressType': 'StreetAddress'}]}, {'RegistrationNumber': '974761076', 'Name': 'Skatteetaten - mva', 'SupplierID': 'PKEY8182436', 'ClosingCreditBalance': '76.00', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'StreetName': 'Fredrik Selmers Vei 4', 'City': 'Oslo', 'PostalCode': '0663', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'Seksjon Økonomi Postboks 560', 'City': 'Lillehammer', 'PostalCode': '2603', 'Country': 'NO', 'AddressType': 'BillingAddress'}]}, {'RegistrationNumber': '', 'Name': 'Ukjent', 'SupplierID': 'PKEY8182448', 'ClosingCreditBalance': '102660.86', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'City': 'Ukjent', 'PostalCode': 'Ukjent', 'AddressType': 'StreetAddress'}]}, {'RegistrationNumber': '', 'Name': 'Diverse leverandør', 'SupplierID': 'PKEY8182450', 'ClosingCreditBalance': '', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'City': 'Ukjent', 'PostalCode': 'Ukjent', 'AddressType': 'StreetAddress'}]}, {'RegistrationNumber': '987290986', 'Name': 'XLEDGER AS', 'SupplierID': 'XLAS', 'ClosingCreditBalance': '', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'StreetName': 'Postboks 6662', 'City': 'Oslo', 'PostalCode': '0609', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'Postboks 6662 Etterstad', 'City': 'Oslo', 'PostalCode': '0609', 'Country': 'NO', 'AddressType': 'BillingAddress'}]}, {'RegistrationNumber': '981937597', 'Name': 'XSERVICES Norge AS', 'SupplierID': 'XSN', 'ClosingCreditBalance': '', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'StreetName': 'Postboks 6662', 'City': 'Oslo', 'PostalCode': '0609', 'Country': 'NO', 'AddressType': 'StreetAddress'}]}, {'RegistrationNumber': '994442295', 'Name': 'Nedre Romerike Kemnerkontor', 'SupplierID': '3026', 'ClosingCreditBalance': '143847.00', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'StreetName': 'Kanalveien 18', 'City': 'Lillestrøm', 'PostalCode': '2004', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'Postboks 313', 'City': 'Lillestrøm', 'PostalCode': '2001', 'Country': 'NO', 'AddressType': 'BillingAddress'}]}, {'RegistrationNumber': '918874224', 'Name': 'Accountflow AS', 'SupplierID': 'PKEY20194411', 'ClosingCreditBalance': '', 'Contact': {'ContactPerson': {'FirstName': 'Ukjent', 'LastName': 'Ukjent'}, 'Email': 'Ukjent', 'Website': 'Ukjent'}, 'NaceCode': '', 'Address': [{'StreetName': 'C/O Robert Bansal Kantarellvegen 16', 'City': 'Frogner', 'PostalCode': '2016', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'C/O Robert Bansal Kantarellveg ...

# %%
# Transactions
with open("/content/transactions.json", "w") as t:
    t.write(json.dumps(Company.getTransactions(test)))
# print(Company.getTransactions(test))

# %%
# Accounts
with open("/content/accounts.json", "w") as t:
    t.write(json.dumps(Company.getAccounts(test)))
print(Company.getAccounts(test))
# Out:
# {'RegistrationNumber': '918874224', 'Name': 'Accountflow AS', 'Accounts': [{'AccountID': '2770', 'AccountDescription': 'Skyldig arbeidsgiveravgift', 'StandardAccountID': '27', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '2813.19'}, {'AccountID': '1000', 'AccountDescription': 'Forskning og utvikling, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1005', 'AccountDescription': 'Forskning og utvikling, egenutviklet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1020', 'AccountDescription': 'Konsesjoner, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1025', 'AccountDescription': 'Konsesjoner, egenutviklet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1030', 'AccountDescription': 'Patenter, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1035', 'AccountDescription': 'Patenter, egenutviklet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1040', 'AccountDescription': 'Lisenser, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1045', 'AccountDescription': 'Lisenser, egenutviklet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1050', 'AccountDescription': 'Varemerker, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1051', 'AccountDescription': 'Varemerker, ervervet - akkumulerte avskrivninger', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1055', 'AccountDescription': 'Varemerker, egenutviklet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1060', 'AccountDescription': 'Andre rettigheter, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1065', 'AccountDescription': 'Andre rettigherer, egenutviklet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1070', 'AccountDescription': 'Utsatt skattefordel', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1080', 'AccountDescription': 'Goodwill, ervervet', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1081', 'AccountDescription': 'Goodwill, ervervet - akk. avskrivninger', 'StandardAccountID': '10', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1100', 'AccountDescription': 'Bygninger', 'StandardAccountID': '11', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1101', 'AccountDescription': 'Bygninger - akkumulerte avskrivninger', 'StandardAccountID': '11', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1120', 'AccountDescription': 'Bygningsmessig anlegg', 'StandardAccountID': '11', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1130', 'AccountDescription': 'Anlegg under utførelse', 'StandardAccountID': '11', 'AccountType': 'GL', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'AccountID': '1140', 'AccountDescription': 'Jor ...

# %%
# Test Company
test = Company(header, suppliers, journal, kontoplan)
print(test)
# test.setSuppliers(suppliers)
# test.setSuppliers(suppliers)
# print(json.dumps(Company.getCompanyDict(test)))
# print(Company.getCompany(test))
# Out:
# Org.nr.: 918874224
# Navn: Accountflow AS
# Adresse: [{'StreetName': 'Pilestredet 75C', 'City': 'Oslo', 'PostalCode': '0354', 'Country': 'NO', 'AddressType': 'StreetAddress'}]
# Kontakt: {'FirstName': 'Daniel', 'LastName': 'Jara'}
#
# Kontoplan: 627
# Leverandør 1: 79
# Transaksjoner: 171

# %% [markdown]
# #Class Suppliers

# %%
class Supplier:
    
    def __init__(self, supplier):
        self.RegistrationNumber = supplier.get('RegistrationNumber', "") # Optional
        self.Name = supplier['Name'] # Mandatory
        self.SupplierID = supplier.get("SupplierID", "") #M
        self.ClosingCreditBalance = supplier.get("ClosingCreditBalance", "") #M
        self.Contact = supplier.get("Contact", {})

        if "Contact" in supplier:
            if "ContactPerson" in supplier["Contact"]:
                self.Contact["ContactPerson"] = supplier["Contact"]["ContactPerson"]
            else: 
                self.Contact.update({"ContactPerson": {"FirstName": "Ukjent", "LastName": "Ukjent"}}) #O
        else:
            self.Contact.update({"ContactPerson": {"FirstName": "Ukjent", "LastName": "Ukjent"}}) #O
            self.Contact.update({"Email": "Ukjent"})
            self.Contact.update({"Website": "Ukjent"})  #O

        if "PartyInfo" in supplier:
            self.NaceCode = supplier["PartyInfo"].get("NaceCode", "") #O
        else:
            self.NaceCode = ""

        self.Address = []
        if "Address" in supplier:
            self.setAddress(supplier)

        # Supplier.counter += 1

    def __str__(self):
        return f'''
Org.nr.: {self.RegistrationNumber}
Navn: {self.Name}
Adresse: {self.Address}
Kontakt: {self.Contact}\n
Leverandør ID: {self.SupplierID}
'''


    # Set Address
    def setAddress(self, supplier):
        if isinstance(supplier['Address'], dict):
            self.Address.append(supplier['Address'])
        else:
            self.Address = supplier["Address"]

    #getSupplier
    def getSupplier(self):
        # suppliersJson = json.dumps(self)
        return copy.deepcopy(self.__dict__)
        # return self.__dict__

# %%
# Test Suppliers
print(Suppliers.get)

# %% [markdown]
# #Class Transaction

# %%
class Transaction:
    def __init__(self, transaction):
        self._TransactionID = transaction['TransactionID']
        self._Period = transaction['Period']
        self._PeriodYear = transaction['PeriodYear']
        self._TransactionDate = transaction['TransactionDate']
        
        description = transaction.get("Description", "")
        if description == None:
            self._Description = ""
        else:
            self._Description = description
            
        # self._Description = transaction['Description']
        self._Lines = []

        self.setLines(transaction["Line"])

    def __str__(self):
        return f'''
        {self._TransactionID}
        {self._Period}
        {self._Description}
        {len(self._Lines)}
        '''
        # Set Lines
    def setLines(self, transaction):
        for line in transaction:
            # print(line)
            line = Line(line)
            # Append the lines as objects
            self._Lines.append(line)

    #getTransaction
    def getTransaction(self):
        trans = {
            "TransactionID": self._TransactionID,
            "Period": self._Period,
            "PeriodYear": self._PeriodYear,
            "TransactionDate": self._TransactionDate,
            "Description": self._Description,
            "Lines": []
        }

        for line in self._Lines:
            trans["Lines"].append(line.getLine())

        # print(trans)
        return trans #self.__dict__

# %% [markdown]
# #Class Line:

# %%
class Line:
    def __init__(self, line):
        self.RecordID = line["RecordID"]
        self.AccountID = line["AccountID"]
        self.SupplierID = line.get("SupplierID", "")

        description = line.get("Description", "")
        if description == None:
            self.Description = ""
        else:
            self.Description = description

        self.CreditAmount = line.get("CreditAmount", {"Amount": ""})
        self.DebitAmount = line.get("DebitAmount", {"Amount": ""})

    def __str__(self):
        return f'''
AccountID: {self.AccountID}
Description: {self.Description}
Credit: {self.CreditAmount}
Debit: {self.DebitAmount} '''

    #getLines
    def getLine(self):
        # print(self)
        # return json.dumps(copy.deepcopy(self.__dict__))
        return copy.deepcopy(self.__dict__)
        # return self.__dict__

# %% [markdown]
# #Main

# %%
## Main
# Parsing xml
namespaces = {
    'n1': None, # skip this namespace
}

data = json.dumps(xmltodict.parse(open('/content/drive/MyDrive/Scope321/Standards/SAF-T/saftOriginal-edit.xml').read(), namespaces=namespaces))
print(data)
print(type(data))

# Make the data a dictionary i python
my_dict = json.loads(data)

# Header
header = my_dict["AuditFile"]["Header"]
print("Header:",header)

# Suppliers
suppliers = my_dict["AuditFile"]["MasterFiles"]["Suppliers"]["Supplier"]
print("Suppliers ->", suppliers)

# with open("/content/suppliers.txt", "w") as file:

    # file.write(json.dumps(suppliers))

# Account (kontoplan)
kontoplan = my_dict["AuditFile"]["MasterFiles"]["GeneralLedgerAccounts"]["Account"]

# Accounts Payable or Assorted
journals = my_dict["AuditFile"]["GeneralLedgerEntries"]["Journal"]
journal = transactions(journals)
# Out:
# {"AuditFile": {"@xmlns:n1": "urn:StandardAuditFile-Taxation-Financial:NO", "Header": {"AuditFileVersion": "1.10", "AuditFileCountry": "NO", "AuditFileDateCreated": "2020-12-02", "SoftwareCompanyName": "Xledger AS", "SoftwareID": "Xledger", "SoftwareVersion": "2019-R3", "Company": {"RegistrationNumber": "918874224", "Name": "Accountflow AS", "Address": {"StreetName": "Pilestredet 75C", "City": "Oslo", "PostalCode": "0354", "Country": "NO", "AddressType": "StreetAddress"}, "Contact": {"ContactPerson": {"FirstName": "Daniel", "LastName": "Jara"}}, "TaxRegistration": {"TaxRegistrationNumber": "918874224MVA", "TaxAuthority": "Skatteetaten"}, "BankAccount": [{"BankAccountNumber": "15038894525", "BankAccountName": "Accountflow AS", "BIC": "DNBANOKKXXX", "CurrencyCode": "NOK", "GeneralLedgerAccountID": "1920PKEY92783"}, {"BankAccountNumber": "62068609041", "BankAccountName": "Accountflow AS", "BIC": "NDEANOKKXXX", "CurrencyCode": "NOK", "GeneralLedgerAccountID": "1930"}, {"BankAccountNumber": "65806886984", "BankAccountName": "Accountflow AS", "BIC": "NDEANOKKXXX", "CurrencyCode": "NOK", "GeneralLedgerAccountID": "2380"}, {"BankAccountNumber": "15061809012", "BankAccountName": "Accountflow AS", "BIC": "DNBANOKKXXX", "CurrencyCode": "NOK", "GeneralLedgerAccountID": "1950"}, {"BankAccountNumber": "32073268493", "BankAccountName": "Accountflow AS", "BIC": "SPRONO22XXX", "CurrencyCode": "NOK", "GeneralLedgerAccountID": "1921"}]}, "DefaultCurrencyCode": "NOK", "SelectionCriteria": {"PeriodStart": "1", "PeriodStartYear": "2020", "PeriodEnd": "11", "PeriodEndYear": "2020"}, "TaxAccountingBasis": "A"}, "MasterFiles": {"GeneralLedgerAccounts": {"Account": [{"AccountID": "2770", "AccountDescription": "Skyldig arbeidsgiveravgift", "StandardAccountID": "27", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "2813.19"}, {"AccountID": "1000", "AccountDescription": "Forskning og utvikling, ervervet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1005", "AccountDescription": "Forskning og utvikling, egenutviklet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1020", "AccountDescription": "Konsesjoner, ervervet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1025", "AccountDescription": "Konsesjoner, egenutviklet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1030", "AccountDescription": "Patenter, ervervet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1035", "AccountDescription": "Patenter, egenutviklet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1040", "AccountDescription": "Lisenser, ervervet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1045", "AccountDescription": "Lisenser, egenutviklet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1050", "AccountDescription": "Varemerker, ervervet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1051", "AccountDescription": "Varemerker, ervervet - akkumulerte avskrivninger", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1055", "AccountDescription": "Varemerker, egenutviklet", "StandardAccountID": "10", "AccountType": "GL", "OpeningDebitBalance": "0.00", "ClosingDebitBalance": "0.00"}, {"AccountID": "1060", "AccountDescription": "Andre rettigheter, ervervet", "StandardAccountID": "10", "Accoun ...
# <class 'str'>
# Header: {'AuditFileVersion': '1.10', 'AuditFileCountry': 'NO', 'AuditFileDateCreated': '2020-12-02', 'SoftwareCompanyName': 'Xledger AS', 'SoftwareID': 'Xledger', 'SoftwareVersion': '2019-R3', 'Company': {'RegistrationNumber': '918874224', 'Name': 'Accountflow AS', 'Address': {'StreetName': 'Pilestredet 75C', 'City': 'Oslo', 'PostalCode': '0354', 'Country': 'NO', 'AddressType': 'StreetAddress'}, 'Contact': {'ContactPerson': {'FirstName': 'Daniel', 'LastName': 'Jara'}}, 'TaxRegistration': {'TaxRegistrationNumber': '918874224MVA', 'TaxAuthority': 'Skatteetaten'}, 'BankAccount': [{'BankAccountNumber': '15038894525', 'BankAccountName': 'Accountflow AS', 'BIC': 'DNBANOKKXXX', 'CurrencyCode': 'NOK', 'GeneralLedgerAccountID': '1920PKEY92783'}, {'BankAccountNumber': '62068609041', 'BankAccountName': 'Accountflow AS', 'BIC': 'NDEANOKKXXX', 'CurrencyCode': 'NOK', 'GeneralLedgerAccountID': '1930'}, {'BankAccountNumber': '65806886984', 'BankAccountName': 'Accountflow AS', 'BIC': 'NDEANOKKXXX', 'CurrencyCode': 'NOK', 'GeneralLedgerAccountID': '2380'}, {'BankAccountNumber': '15061809012', 'BankAccountName': 'Accountflow AS', 'BIC': 'DNBANOKKXXX', 'CurrencyCode': 'NOK', 'GeneralLedgerAccountID': '1950'}, {'BankAccountNumber': '32073268493', 'BankAccountName': 'Accountflow AS', 'BIC': 'SPRONO22XXX', 'CurrencyCode': 'NOK', 'GeneralLedgerAccountID': '1921'}]}, 'DefaultCurrencyCode': 'NOK', 'SelectionCriteria': {'PeriodStart': '1', 'PeriodStartYear': '2020', 'PeriodEnd': '11', 'PeriodEndYear': '2020'}, 'TaxAccountingBasis': 'A'}
# Suppliers -> [{'RegistrationNumber': '971228865', 'Name': 'Stiftelsen Handelshøyskolen Bi', 'Address': [{'StreetName': 'Nydalsveien 37', 'City': 'Oslo', 'PostalCode': '0484', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'City': 'Oslo', 'PostalCode': '0442', 'Country': 'NO', 'AddressType': 'BillingAddress'}], 'TaxRegistration': {'TaxRegistrationNumber': '971228865MVA'}, 'BankAccount': {'BankAccountNumber': '15034223006'}, 'SupplierID': 'PKEY6377196', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'Name': 'Diverse leverandør', 'Address': {'City': 'Ukjent', 'PostalCode': 'Ukjent', 'AddressType': 'StreetAddress'}, 'BankAccount': {'BankAccountNumber': '0'}, 'SupplierID': 'PKEY8182428', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'RegistrationNumber': '974761076', 'Name': 'Skatteetaten - mva', 'Address': [{'StreetName': 'Fredrik Selmers Vei 4', 'City': 'Oslo', 'PostalCode': '0663', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'Seksjon Økonomi Postboks 560', 'City': 'Lillehammer', 'PostalCode': '2603', 'Country': 'NO', 'AddressType': 'BillingAddress'}], 'TaxRegistration': {'TaxRegistrationNumber': '974761076MVA'}, 'BankAccount': {'BankAccountNumber': '76940518888'}, 'SupplierID': 'PKEY8182436', 'OpeningDebitBalance': '0.00', 'ClosingCreditBalance': '76.00'}, {'Name': 'Ukjent', 'Address': {'City': 'Ukjent', 'PostalCode': 'Ukjent', 'AddressType': 'StreetAddress'}, 'SupplierID': 'PKEY8182448', 'OpeningDebitBalance': '0.00', 'ClosingCreditBalance': '102660.86'}, {'Name': 'Diverse leverandør', 'Address': {'City': 'Ukjent', 'PostalCode': 'Ukjent', 'AddressType': 'StreetAddress'}, 'BankAccount': {'BankAccountNumber': '47210408021'}, 'SupplierID': 'PKEY8182450', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'RegistrationNumber': '987290986', 'Name': 'XLEDGER AS', 'Address': [{'StreetName': 'Postboks 6662', 'City': 'Oslo', 'PostalCode': '0609', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'Postboks 6662 Etterstad', 'City': 'Oslo', 'PostalCode': '0609', 'Country': 'NO', 'AddressType': 'BillingAddress'}], 'TaxRegistration': {'TaxRegistrationNumber': '987290986MVA'}, 'BankAccount': {'BankAccountNumber': '50100681177', 'BIC': 'DNBANOKKXXX'}, 'SupplierID': 'XLAS', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'RegistrationNumber': '981937597', 'Name': 'XSERVICES Norge AS', 'Address': {'StreetName': 'Postboks 6662', 'City': 'Oslo', 'PostalCode': '0609', 'Country': 'NO', 'AddressType': 'StreetAddress'}, 'BankAccount': {'BankAccountNumber': '16040471859', 'BIC': 'UBNONOKKXXX'}, 'SupplierID': 'XSN', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'RegistrationNumber': '994442295', 'Name': 'Nedre Romerike Kemnerkontor', 'Address': [{'StreetName': 'Kanalveien 18', 'City': 'Lillestrøm', 'PostalCode': '2004', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'Postboks 313', 'City': 'Lillestrøm', 'PostalCode': '2001', 'Country': 'NO', 'AddressType': 'BillingAddress'}], 'BankAccount': {'BankAccountNumber': '63450730264'}, 'SupplierID': '3026', 'OpeningDebitBalance': '0.00', 'ClosingCreditBalance': '143847.00'}, {'RegistrationNumber': '918874224', 'Name': 'Accountflow AS', 'Address': [{'StreetName': 'C/O Robert Bansal Kantarellvegen 16', 'City': 'Frogner', 'PostalCode': '2016', 'Country': 'NO', 'AddressType': 'StreetAddress'}, {'StreetName': 'C/O Robert Bansal Kantarellvegen 16', 'City': 'Frogner', 'PostalCode': '2016', 'Country': 'NO', 'AddressType': 'BillingAddress'}, {'StreetName': 'C/O Robert Bansal Kantarellvegen 16', 'City': 'Frogner', 'PostalCode': '2016', 'Country': 'NO', 'AddressType': 'ShipToAddress'}], 'TaxRegistration': {'TaxRegistrationNumber': '918874224MVA'}, 'BankAccount': {'BankAccountNumber': '15038894525'}, 'SupplierID': 'PKEY20194411', 'OpeningDebitBalance': '0.00', 'ClosingDebitBalance': '0.00'}, {'RegistrationNumber': '919426004', 'Name': 'Finance Innovation', 'Address': [{'StreetName': 'L ...
# Journals: [{'JournalID': '2020BA', 'Description': 'Bankbilag 2020', 'Type': 'BA', 'Transaction': [{'TransactionID': 'BA##62-2004', 'Period': '4', 'PeriodYear': '2020', 'TransactionDate': '2020-04-07', 'Description': None, 'SystemEntryDate': '2020-04-07', 'GLPostingDate': '2020-04-07', 'Line': [{'RecordID': 'GL276204134', 'AccountID': '1920PKEY92783', 'Description': '054279880094100595834739445391Usd 11,95 Aws EmeaValutakurs:    10,8468', 'CreditAmount': {'Amount': '129.62', 'CurrencyCode': 'USD', 'CurrencyAmount': '11.95', 'ExchangeRate': '10.84686192'}}, {'RecordID': 'GL276204149', 'AccountID': '8160', 'Description': None, 'DebitAmount': {'Amount': '6.52', 'CurrencyCode': 'USD', 'CurrencyAmount': '0.00', 'ExchangeRate': '0'}}, {'RecordID': 'SL96292333', 'AccountID': '2400', 'ValueDate': '2020-04-07', 'SupplierID': 'PKEY21170996', 'Description': None, 'DebitAmount': {'Amount': '
# <class 'list'>
# Ledger not found

# %%
# Main part
af = Company(header, suppliers, journal, kontoplan) #

# af.setKontoplan(kontoPlan)

# af.setSuppliers(suppliers)

# af.setTransactions(journal)

    # Push data to Mongo db
    # Start a connection to database
    #connection = Connect.get_connection()

    # Access the Database
    #db = connection.saft_v2

    # Insert data into Database.Collection
mongodata = af.getCompany()
    #db.full.insert_one(mongodata)
print(mongodata)
print(type(mongodata))
data = json.dumps(mongodata)
print(type(data))
print(json.dumps(mongodata))

# %%
# Install dnspython
# !pip install dnspython
# Out:
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.1.0)

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (3.11.4)

# %%
# Push data to Mongo db
# Start a connection to database
connection = Connect.get_connection()

# Access the Database
db = connection.saft

# Insert data into Database.Collection
data = Company.getAccounts(test)
db.accounts.insert_one(data)

# Insert data into Database.Collection
data1 = Company.getSuppliers(test)
db.suppliers.insert_one(data1)

# Insert data into Database.Collection
data2 = Company.getTransactions(test)
db.transactions.insert_one(data2)

# Insert data into Database.Collection
db.company.insert_one(header)
# Out:
# {'TransactionID': 'AP##174-2001', 'Period': '1', 'PeriodYear': '2020', 'TransactionDate': '2020-01-01', 'Description': 'Kvittering Taxi', 'Lines': [{'RecordID': 'SL98761282', 'AccountID': '2911', 'SupplierID': 'PKEY20856802', 'Description': '', 'CreditAmount': {'Amount': '205.00'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL282338957', 'AccountID': '7140', 'SupplierID': '', 'Description': 'Hjem fra Startup event', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '183.04'}}, {'RecordID': 'GL282338958', 'AccountID': '2712', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '21.96'}}]}
# {'TransactionID': 'AP##68-2006', 'Period': '6', 'PeriodYear': '2020', 'TransactionDate': '2020-06-28', 'Description': '', 'Lines': [{'RecordID': 'GL276203555', 'AccountID': '6552', 'SupplierID': '', 'Description': 'Office 365 E3 Developer 27.06.2020-26.07.2020', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1256.13'}}, {'RecordID': 'GL276203557', 'AccountID': '2708', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1256.13'}}, {'RecordID': 'GL276203558', 'AccountID': '2709', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '1256.13'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL276203559', 'AccountID': '2703', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '314.03'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL276203560', 'AccountID': '2725', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '314.03'}}, {'RecordID': 'SL96292189', 'AccountID': '2400', 'SupplierID': 'PKEY21170989', 'Description': '', 'CreditAmount': {'Amount': '1256.13'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP##13-2006', 'Period': '6', 'PeriodYear': '2020', 'TransactionDate': '2020-06-01', 'Description': '', 'Lines': [{'RecordID': 'GL258400210', 'AccountID': '6300', 'SupplierID': '', 'Description': 'Husleie kontor 01.06.20-30.06.20', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '20000.00'}}, {'RecordID': 'GL258400211', 'AccountID': '2710', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '5000.00'}}, {'RecordID': 'SL90216970', 'AccountID': '2400', 'SupplierID': 'PKEY20194420', 'Description': '', 'CreditAmount': {'Amount': '25000.00'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP##54-2005', 'Period': '5', 'PeriodYear': '2020', 'TransactionDate': '2020-05-31', 'Description': '', 'Lines': [{'RecordID': 'GL276203344', 'AccountID': '6552', 'SupplierID': '', 'Description': 'Google Cloud Platform Mai 2020', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '5715.78'}}, {'RecordID': 'GL276203345', 'AccountID': '2708', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '5715.78'}}, {'RecordID': 'GL276203346', 'AccountID': '2709', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '5715.78'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL276203347', 'AccountID': '2703', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '1428.95'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL276203348', 'AccountID': '2725', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1428.95'}}, {'RecordID': 'SL96292143', 'AccountID': '2400', 'SupplierID': 'PKEY21170731', 'Description': '', 'CreditAmount': {'Amount': '5715.78'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP
 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1480.59'}}, {'RecordID': 'SL96438296', 'AccountID': '2400', 'SupplierID': 'PKEY21170731', 'Description': '', 'CreditAmount': {'Amount': '1480.59'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP##22-2008', 'Period': '8', 'PeriodYear': '2020', 'TransactionDate': '2020-08-05', 'Description': '', 'Lines': [{'RecordID': 'GL266439477', 'AccountID': '6915', 'SupplierID': '', 'Description': 'Kreditnota utkjøp binding august 2020', 'CreditAmount': {'Amount': '27000.00'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL266439479', 'AccountID': '2710', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '6750.00'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'SL93152462', 'AccountID': '2400', 'SupplierID': 'PKEY20194433', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '33750.00'}}]}
# {'TransactionID': 'AP##138-2006', 'Period': '6', 'PeriodYear': '2020', 'TransactionDate': '2020-06-02', 'Description': '', 'Lines': [{'RecordID': 'GL277284252', 'AccountID': '5945', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '5416.00'}}, {'RecordID': 'SL96719671', 'AccountID': '2400', 'SupplierID': 'PKEY20508241', 'Description': '', 'CreditAmount': {'Amount': '5416.00'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP##51-2002', 'Period': '2', 'PeriodYear': '2020', 'TransactionDate': '2020-02-29', 'Description': '', 'Lines': [{'RecordID': 'GL276203314', 'AccountID': '6552', 'SupplierID': '', 'Description': 'Google Cloud Platform Februar 2020', 'CreditAmount': {'Amount': '1365.23'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL276203322', 'AccountID': '2703', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '341.31'}}, {'RecordID': 'GL276203323', 'AccountID': '2708', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '1365.23'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL276203324', 'AccountID': '2709', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1365.23'}}, {'RecordID': 'GL276203325', 'AccountID': '2725', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': '341.31'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'SL96292136', 'AccountID': '2400', 'SupplierID': 'PKEY21170731', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1365.23'}}]}
# {'TransactionID': 'AP##16-2004', 'Period': '4', 'PeriodYear': '2020', 'TransactionDate': '2020-04-06', 'Description': '', 'Lines': [{'RecordID': 'GL276617053', 'AccountID': '8150', 'SupplierID': '', 'Description': 'Forsinkelsesrente, arbeidsgiveravgift 2020/1', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '178.00'}}, {'RecordID': 'SL96512760', 'AccountID': '2400', 'SupplierID': 'PKEY21187226', 'Description': '', 'CreditAmount': {'Amount': '178.00'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP##147-2007', 'Period': '7', 'PeriodYear': '2020', 'TransactionDate': '2020-07-21', 'Description': '', 'Lines': [{'RecordID': 'GL277319570', 'AccountID': '2710', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '457.99'}}, {'RecordID': 'GL277319572', 'AccountID': '6900', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '1831.95'}}, {'RecordID': 'SL96729288', 'AccountID': '2400', 'SupplierID': 'PKEY21222816', 'Description': '', 'CreditAmount': {'Amount': '2289.94'}, 'DebitAmount': {'Amount': ''}}]}
# {'TransactionID': 'AP##170-2010', 'Period': '10', 'PeriodYear': '2020', 'TransactionDate': '2020-10-26', 'Description': '', 'Lines': [{'RecordID': 'SL98761134', 'AccountID': '2400', 'SupplierID': 'PKEY20508268', 'Description': '', 'CreditAmount': {'Amount': '50000.00'}, 'DebitAmount': {'Amount': ''}}, {'RecordID': 'GL282338305', 'AccountID': '6790', 'SupplierID': '', 'Description': 'Suksesshonorar bistand SkatteFUNN', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '40000.00'}}, {'RecordID': 'GL282338306', 'AccountID': '2710', 'SupplierID': '', 'Description': '', 'CreditAmount': {'Amount': ''}, 'DebitAmount': {'Amount': '10000.00'}}]}

# %%
with open("/content/accounts.json", "w") as t:
    t.write(json.dumps(Company.getAccounts(test)))
